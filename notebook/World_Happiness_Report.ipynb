# %% [markdown]
# # **Abstract**
#
#
# > In years, some economic indicators (e.g. GDP per capita or income level) have been believed to have a positive relationship with people’s happiness across nations. World Happiness Report 2019 considers six indicators related to people’s happiness: GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity and Perceptions of corruption. While recently, some studies found that: education is positively correlated with happiness and inflation has a negative impact on people’s happiness.
# The aims of this study are:
# 1.	To analyze the relationship between happiness and six indicators proposed by WHR, together with 2 self-added indicators (education and inflation).
# 2.	To establish a predictive model with related predictive indicators.

# %% [markdown]
# # **Data preprocess**

# %%
# !pip install shap

# %%
import pandas as pd
import shap
import sklearn
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Primary School Enrollment & Regions

# %%
se_prm_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/SE_Prm/API_SE.PRM.ENRR_DS2_en_csv_v2_4666459.csv'
se_prm = pd.read_csv(se_prm_url)
se_prm
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                            Indicator Name Indicator Code  1960  1961  1962  \
# 0    School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 1    School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 2    School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 3    School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 4    School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# ..                                    ...            ...   ...   ...   ...
# 261  School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 262  School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 263  School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 264  School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
# 265  School enrollment, primary (% gross)    SE.PRM.ENRR   NaN   NaN   NaN
#
#      1963  1964  1965  ...        2012        2013        2014        2015  \
# 0     NaN   NaN   NaN  ...  104.087128  116.039299  117.108093         NaN
# 1     NaN   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 2     NaN   NaN   NaN  ...  103.492394  104.498428  105.919708  103.534523
# 3     NaN   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 4     NaN   NaN   NaN  ...         NaN         NaN         NaN  113.477959
# ..    ...   ...   ...  ...         ...         ...         ...         ...
# 261   NaN   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 262   NaN   NaN   NaN  ...   95.097687   98.173103         NaN         NaN
# 263   NaN   NaN   NaN  ...  103.229202  102.670402  102.704964  105.570389
# 264   NaN   NaN   NaN  ...  108.129646  102.713669  104.331993  101.460480
# 265   NaN   NaN   NaN  ...  112.516792  109.892792         NaN  103.833992
#
#            2016        2017        2018        2019       2020  2021
# 0           NaN         NaN         NaN         NaN        NaN   NaN
# 1           NaN         NaN         NaN         NaN        NaN   NaN
# 2    102.486473  102.175789  103.996162  106.701080        NaN   NaN
# 3           NaN         NaN         NaN         NaN        NaN   NaN
# 4           NaN         NaN         NaN         NaN        NaN   NaN
# ..          ...         ...         ...         ...        ...   ...
# 261         NaN         NaN         NaN         NaN        NaN   NaN
# 262   93.637482         NaN         NaN         NaN        NaN   NaN
# 263  103.184959  100.864731   98.538902   98.374474        NaN   NaN
# 264   98.606979   98.715523         NaN         NaN        NaN   NaN
# 265  101.309677   98.933189   97.750809   97.140213  97.304909   NaN
#
# [266 rows x 66 columns]

# %%
region_prm_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/SE_Prm/Metadata_Country_API_SE.PRM.ENRR_DS2_en_csv_v2_4666459.csv'
region_prm = pd.read_csv(region_prm_url)
region_prm
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName  Unnamed: 5
# 0                          Aruba         NaN
# 1    Africa Eastern and Southern         NaN
# 2                    Afghanistan         NaN
# 3     Africa Western and Central         NaN
# 4                         Angola         NaN
# ..                           ...         ...
# 260                       Kosovo         NaN
# 261                  Yemen, Rep.         NaN
# 262                 South Africa         NaN
# 263                       Zambia         NaN
# 264                     Zimbabwe         NaN
#
# [265 rows x 6 columns]

# %% [markdown]
# ### Secondary School Enrollment & Regions

# %%
region_sec_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/SE_Sec/API_SE.SEC.ENRR_DS2_en_csv_v2_4672725.csv'
region_sec = pd.read_csv(region_sec_url)
region_sec
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name Indicator Code  1960  1961  1962  \
# 0    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 1    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 2    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 3    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 4    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# ..                                      ...            ...   ...   ...   ...
# 261  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 262  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 263  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 264  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 265  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
#
#      1963  1964  1965  ...        2012      2013        2014        2015  \
# 0     NaN   NaN   NaN  ...  111.159767       NaN         NaN         NaN
# 1     NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 2     NaN   NaN   NaN  ...   53.618050  53.57513   52.582901   51.669949
# 3     NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 4     NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# ..    ...   ...   ...  ...         ...       ...         ...         ...
# 261   NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 262   NaN   NaN   NaN  ...   46.912781  49.27726         NaN         NaN
# 263   NaN   NaN   NaN  ...   98.826859       NaN  107.804123  109.444076
# 264   NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 265   NaN   NaN   NaN  ...   51.550991  52.40567         NaN         NaN
#
#            2016        2017        2018        2019  2020  2021
# 0           NaN         NaN         NaN         NaN   NaN   NaN
# 1           NaN         NaN         NaN         NaN   NaN   NaN
# 2     51.655941   53.643200   55.425209         NaN   NaN   NaN
# 3           NaN         NaN         NaN         NaN   NaN   NaN
# 4     50.671478         NaN         NaN         NaN   NaN   NaN
# ..          ...         ...         ...         ...   ...   ...
# 261         NaN         NaN         NaN         NaN   NaN   NaN
# 262   51.580681         NaN         NaN         NaN   NaN   NaN
# 263  107.176948  104.697983  100.511169  102.556663   NaN   NaN
# 264         NaN         NaN         NaN         NaN   NaN   NaN
# 265         NaN         NaN         NaN         NaN   NaN   NaN
#
# [266 rows x 66 columns]

# %%
se_sec_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/SE_Sec/API_SE.SEC.ENRR_DS2_en_csv_v2_4672725.csv'
se_sec = pd.read_csv(se_sec_url)
se_sec
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name Indicator Code  1960  1961  1962  \
# 0    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 1    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 2    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 3    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 4    School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# ..                                      ...            ...   ...   ...   ...
# 261  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 262  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 263  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 264  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
# 265  School enrollment, secondary (% gross)    SE.SEC.ENRR   NaN   NaN   NaN
#
#      1963  1964  1965  ...        2012      2013        2014        2015  \
# 0     NaN   NaN   NaN  ...  111.159767       NaN         NaN         NaN
# 1     NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 2     NaN   NaN   NaN  ...   53.618050  53.57513   52.582901   51.669949
# 3     NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 4     NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# ..    ...   ...   ...  ...         ...       ...         ...         ...
# 261   NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 262   NaN   NaN   NaN  ...   46.912781  49.27726         NaN         NaN
# 263   NaN   NaN   NaN  ...   98.826859       NaN  107.804123  109.444076
# 264   NaN   NaN   NaN  ...         NaN       NaN         NaN         NaN
# 265   NaN   NaN   NaN  ...   51.550991  52.40567         NaN         NaN
#
#            2016        2017        2018        2019  2020  2021
# 0           NaN         NaN         NaN         NaN   NaN   NaN
# 1           NaN         NaN         NaN         NaN   NaN   NaN
# 2     51.655941   53.643200   55.425209         NaN   NaN   NaN
# 3           NaN         NaN         NaN         NaN   NaN   NaN
# 4     50.671478         NaN         NaN         NaN   NaN   NaN
# ..          ...         ...         ...         ...   ...   ...
# 261         NaN         NaN         NaN         NaN   NaN   NaN
# 262   51.580681         NaN         NaN         NaN   NaN   NaN
# 263  107.176948  104.697983  100.511169  102.556663   NaN   NaN
# 264         NaN         NaN         NaN         NaN   NaN   NaN
# 265         NaN         NaN         NaN         NaN   NaN   NaN
#
# [266 rows x 66 columns]

# %% [markdown]
# ### Tertiary School Enrollment & Regions

# %%
region_ter_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/SE_Ter/API_SE.TER.ENRR_DS2_en_csv_v2_4690952.csv'
region_ter = pd.read_csv(region_ter_url)
region_ter
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name Indicator Code  1960  1961  1962  \
# 0    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 1    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 2    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 3    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 4    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# ..                                     ...            ...   ...   ...   ...
# 261  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 262  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 263  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 264  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 265  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
#
#      1963  1964  1965  ...       2012       2013      2014       2015  \
# 0     NaN   NaN   NaN  ...  37.761131  16.195829  16.40542  15.271770
# 1     NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 2     NaN   NaN   NaN  ...        NaN        NaN   8.23068        NaN
# 3     NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 4     NaN   NaN   NaN  ...        NaN   8.838330       NaN   8.400940
# ..    ...   ...   ...  ...        ...        ...       ...        ...
# 261   NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 262   NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 263   NaN   NaN   NaN  ...  19.143660  19.930490  19.80924  22.260929
# 264   NaN   NaN   NaN  ...   4.116030        NaN       NaN        NaN
# 265   NaN   NaN   NaN  ...   6.854140   6.935260       NaN  10.006550
#
#           2016      2017      2018      2019      2020  2021
# 0    15.599210       NaN       NaN       NaN       NaN   NaN
# 1          NaN       NaN       NaN       NaN       NaN   NaN
# 2          NaN       NaN   9.68642       NaN  10.56252   NaN
# 3          NaN       NaN       NaN       NaN       NaN   NaN
# 4     9.336260       NaN       NaN       NaN       NaN   NaN
# ..         ...       ...       ...       ...       ...   ...
# 261        NaN       NaN       NaN       NaN       NaN   NaN
# 262        NaN       NaN       NaN       NaN       NaN   NaN
# 263  20.918449  22.36603  23.80196  23.86656       NaN   NaN
# 264        NaN       NaN       NaN       NaN       NaN   NaN
# 265   8.171440   8.87595       NaN       NaN       NaN   NaN
#
# [266 rows x 66 columns]

# %%
se_ter_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/SE_Ter/API_SE.TER.ENRR_DS2_en_csv_v2_4690952.csv'
se_ter = pd.read_csv(se_ter_url)
se_ter
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name Indicator Code  1960  1961  1962  \
# 0    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 1    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 2    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 3    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 4    School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# ..                                     ...            ...   ...   ...   ...
# 261  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 262  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 263  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 264  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
# 265  School enrollment, tertiary (% gross)    SE.TER.ENRR   NaN   NaN   NaN
#
#      1963  1964  1965  ...       2012       2013      2014       2015  \
# 0     NaN   NaN   NaN  ...  37.761131  16.195829  16.40542  15.271770
# 1     NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 2     NaN   NaN   NaN  ...        NaN        NaN   8.23068        NaN
# 3     NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 4     NaN   NaN   NaN  ...        NaN   8.838330       NaN   8.400940
# ..    ...   ...   ...  ...        ...        ...       ...        ...
# 261   NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 262   NaN   NaN   NaN  ...        NaN        NaN       NaN        NaN
# 263   NaN   NaN   NaN  ...  19.143660  19.930490  19.80924  22.260929
# 264   NaN   NaN   NaN  ...   4.116030        NaN       NaN        NaN
# 265   NaN   NaN   NaN  ...   6.854140   6.935260       NaN  10.006550
#
#           2016      2017      2018      2019      2020  2021
# 0    15.599210       NaN       NaN       NaN       NaN   NaN
# 1          NaN       NaN       NaN       NaN       NaN   NaN
# 2          NaN       NaN   9.68642       NaN  10.56252   NaN
# 3          NaN       NaN       NaN       NaN       NaN   NaN
# 4     9.336260       NaN       NaN       NaN       NaN   NaN
# ..         ...       ...       ...       ...       ...   ...
# 261        NaN       NaN       NaN       NaN       NaN   NaN
# 262        NaN       NaN       NaN       NaN       NaN   NaN
# 263  20.918449  22.36603  23.80196  23.86656       NaN   NaN
# 264        NaN       NaN       NaN       NaN       NaN   NaN
# 265   8.171440   8.87595       NaN       NaN       NaN   NaN
#
# [266 rows x 66 columns]

# %%
FPCPI_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/Inflation_Consumer_price_2019/API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_4690188.csv'
FPCPI = pd.read_csv(FPCPI_url)
FPCPI
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name  Indicator Code      1960  \
# 0    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 2    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 4    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# ..                                     ...             ...       ...
# 261  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 262  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 263  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG  1.288859
# 264  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 265  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
#
#          1961      1962     1963      1964      1965  ...       2012  \
# 0         NaN       NaN      NaN       NaN       NaN  ...   0.627472
# 1         NaN       NaN      NaN       NaN       NaN  ...   9.158707
# 2         NaN       NaN      NaN       NaN       NaN  ...   6.441213
# 3         NaN       NaN      NaN       NaN       NaN  ...   4.578375
# 4         NaN       NaN      NaN       NaN       NaN  ...  10.277905
# ..        ...       ...      ...       ...       ...  ...        ...
# 261       NaN       NaN      NaN       NaN       NaN  ...   2.476738
# 262       NaN       NaN      NaN       NaN       NaN  ...   9.885387
# 263  2.102374  1.246285  1.33797  2.534973  4.069029  ...   5.724658
# 264       NaN       NaN      NaN       NaN       NaN  ...   6.575900
# 265       NaN       NaN      NaN       NaN       NaN  ...   3.725327
#
#           2013      2014       2015       2016       2017       2018  \
# 0    -2.372065  0.421441   0.474764  -0.931196  -1.028282   3.626041
# 1     5.750981  5.370290   5.250171   6.571396   6.399343   4.720811
# 2     7.385772  4.673996  -0.661709   4.383892   4.975952   0.626149
# 3     2.439201  1.758052   2.130268   1.494564   1.764635   1.784050
# 4     8.777814  7.280387   9.150372  30.695313  29.843587  19.628608
# ..         ...       ...        ...        ...        ...        ...
# 261   1.767324  0.428958  -0.536929   0.273169   1.488234   1.053798
# 262  10.968442  8.104726        NaN        NaN        NaN        NaN
# 263   5.784469  6.129838   4.540642   6.571396   5.184247   4.517165
# 264   6.977676  7.806876  10.110593  17.869730   6.577312   7.494572
# 265   1.634950 -0.197785  -2.430968  -1.543670   0.893962  10.618866
#
#            2019        2020       2021
# 0      4.257462         NaN        NaN
# 1      4.120246    5.404815   7.240978
# 2      2.302373         NaN        NaN
# 3      1.758565    2.492522   3.925603
# 4     17.081215         NaN        NaN
# ..          ...         ...        ...
# 261    2.675992    0.198228   3.353691
# 262         NaN         NaN        NaN
# 263    4.120246    3.210036   4.611672
# 264    9.150316   15.732585  22.021234
# 265  255.304991  557.201817  98.546105
#
# [266 rows x 66 columns]

# %%
WHR_url = 'https://raw.githubusercontent.com/YongyanDeng/Word_Happiness_Report/main/data/World_Happiness_Report_2019.csv'
WHR = pd.read_csv(WHR_url)
WHR
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %% [markdown]
# # **Modeling**
